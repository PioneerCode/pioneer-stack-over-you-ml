# %% [markdown]
# # Statistics

# %%
import sys
import os

sys.path.insert(0,os.path.join(os.getcwd(), os.pardir,  'src', 'data'))
import stack_data

sys.path.insert(0,os.path.join(os.getcwd(), os.pardir,  'src', 'features'))
import encoded

# %matplotlib inline

# %% [markdown]
# ## Raw

# %% [markdown]
# ### Explore

# %%
raw_data = stack_data.get_data()
raw_data.head()
# Out:
#                                         Professional  \
# 0                                            Student
# 1                                            Student
# 2                             Professional developer
# 3  Professional non-developer who sometimes write...
# 4                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Data columns (total 8 columns):
# Professional       51392 non-null object
# ProgramHobby       51392 non-null object
# Country            51392 non-null object
# University         51392 non-null object
# FormalEducation    51392 non-null object
# MajorUndergrad     42841 non-null object
# YearsProgram       51145 non-null object
# DeveloperType      36125 non-null object
# dtypes: object(8)
# memory usage: 3.1+ MB

# %%
raw_data.describe(include='all')
# Out:
#                   Professional               ProgramHobby        Country  \
# count                    51392                      51392          51392
# unique                       5                          4            201
# top     Professional developer  Yes, I program as a hobby  United States
# freq                     36131                      24801          11455
#
#        University    FormalEducation  \
# count       51392              51392
# unique          4                  9
# top            No  Bachelor's degree
# freq        37543              21609
#
#                                   MajorUndergrad      YearsProgram  \
# count                                      42841             51145
# unique                                        16                21
# top     Computer science or software engineering  20 or more years
# freq                                       21409              8817
#
#         DeveloperType
# count           36125
# ...

# %%
# Developer Type visual count
display(raw_data.DeveloperType.value_counts())
# Out:
# Web developer                                                                                                                                                                                                                                                                                                                10683
# Web developer; Desktop applications developer                                                                                                                                                                                                                                                                                 1849
# Mobile developer                                                                                                                                                                                                                                                                                                              1556
# ...

# %% [markdown]
# ## Lable Categorical Encoded

# %% [markdown]
# ### Explore

# %%
# Review the "Label encode all categorical data" method
encoded_data = encoded.get_encoded(raw_data, stack_data.LABEL_NAME)
encoded_data.head()
# Out:
#    Professional  ProgramHobby  Country  University  FormalEducation  \
# 0             0             3      143           1                0
# 1             0             3      106           1                4
# 2             0             0       23           1                0
# 3             0             3       45           1                8
# 4             0             2      143           1                6
#
#    MajorUndergrad  YearsProgram  DeveloperType
# 0               8            12             10
# 1               8             1             13
# 2               8             4             13
# 3               8             6             13
# 4               6            12              5

# %%
encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16747 entries, 0 to 16746
# Data columns (total 8 columns):
# Professional       16747 non-null int64
# ProgramHobby       16747 non-null int64
# Country            16747 non-null int64
# University         16747 non-null int64
# FormalEducation    16747 non-null int64
# MajorUndergrad     16747 non-null int64
# YearsProgram       16747 non-null int64
# DeveloperType      16747 non-null int64
# dtypes: int64(8)
# memory usage: 1.0 MB

# %%
encoded_data.describe(include='all')
# Out:
#        Professional  ProgramHobby       Country    University  \
# count       16747.0  16747.000000  16747.000000  16747.000000
# mean            0.0      1.676181     91.809697      1.186242
# std             0.0      1.082441     47.905216      0.529332
# min             0.0      0.000000      0.000000      0.000000
# 25%             0.0      1.000000     45.000000      1.000000
# 50%             0.0      2.000000    105.000000      1.000000
# 75%             0.0      2.000000    143.000000      1.000000
# max             0.0      3.000000    152.000000      3.000000
#
#        FormalEducation  MajorUndergrad  YearsProgram  DeveloperType
# count     16747.000000    16747.000000  16747.000000   16747.000000
# mean          2.572401        8.209411     11.230788      10.489341
# std           2.999910        3.318538      5.628476       3.945457
# min           0.000000        0.000000      0.000000       0.000000
# ...

# %%
# Developer Type visual count
encoded_data.DeveloperType.value_counts()
# Out:
# 13    10683
# 9      1556
# 2      1433
# 10     1174
# 5       664
# 4       485
# 0       249
# 3       192
# 11      102
# 1        73
# 7        55
# 8        44
# 12       31
# 6         6
# Name: DeveloperType, dtype: int64

# %%
# Developer Type visual count
encoded_data.DeveloperType.value_counts().plot(kind='bar',rot = 0, title='Developer Type')
